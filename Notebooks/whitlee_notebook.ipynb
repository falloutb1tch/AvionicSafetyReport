# %% [markdown]
# # Exploratory Notebook

# %% [markdown]
# First, we must import and explore the given data.

# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/Aviation_Data.csv')
df.head()
# Out:
# C:\Users\rac753\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
# ...

# %% [markdown]
# As we can see from the first five rows of data, we have quite a lot of information here! Let's look a little more specifically.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %% [markdown]
# As we can see, this dataframe contains 31 columns and some 90,000 rows. There are many nulls, and the data types are object and float. As a first beginning thought, we will need to transform the "Event.Date" column to a "datetime" object, and handle all the nulls we see here.

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %% [markdown]
# In the above, we can see some simple statistical data for the columns with integers. Some of these may be important during the course of our data work.

# %%
df["Date"] = pd.to_datetime(df["Event.Date"])
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
# 3       EUREKA, CA  United States      NaN       NaN          NaN
# 4       Canton, OH  United States      NaN       NaN          NaN
#
#   Airport.Name  ... Air.carrier Total.Fatal.Injuries Total.Serious.Injuries  \
# 0          NaN  ...         NaN                  2.0                    0.0
# ...

# %% [markdown]
# As seen here, I've now created a new column titled "Date" which transforms the "Event.Date" object into a usable date. This might be useful later as we try to show crashes over timeframe and/or the timepoint at which those crashes occurred for which planes.

# %% [markdown]
# Now, the next step will be removing the NANs as we do not need them here and most of them don't impact the data we need.

# %%
df['Make']
# Out:
# 0                           Stinson
# 1                             Piper
# 2                            Cessna
# 3                          Rockwell
# 4                            Cessna
#                     ...
# 90343                         PIPER
# 90344                      BELLANCA
# 90345    AMERICAN CHAMPION AIRCRAFT
# 90346                        CESSNA
# 90347                         PIPER
# Name: Make, Length: 90348, dtype: object

# %%
df['Model']
# Out:
# 0            108-3
# 1         PA24-180
# 2             172M
# 3              112
# 4              501
#            ...
# 90343    PA-28-151
# 90344         7ECA
# 90345        8GCBC
# 90346         210N
# 90347    PA-24-260
# Name: Model, Length: 90348, dtype: object

# %%
df = df.drop('Latitude', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-1529f7ade74c> in <module>
# ----> 1 df = df.drop('Latitude', axis=1)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Longitude Airport.Code Airport.Name  \
# ...

# %%
df = df.drop('Longitude', axis=1)

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Airport.Code Airport.Name  \
# 0      MOOSE CREEK, ID  United States          NaN          NaN
# ...

# %%
df = df.drop('Airport.Code', axis=1)

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Airport.Name Injury.Severity  \
# 0      MOOSE CREEK, ID  United States          NaN        Fatal(2)
# ...

# %%
df['Country'].value_counts()
# Out:
# United States        82248
# Brazil                 374
# Canada                 359
# Mexico                 358
# United Kingdom         344
#                      ...
# Guernsey                 1
# Eritrea                  1
# Wallis and Futuna        1
# Ivory Coast              1
# Anguilla                 1
# Name: Country, Length: 219, dtype: int64

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Airport.Name Injury.Severity  \
# 0  MOOSE CREEK, ID  United States          NaN        Fatal(2)
# 1   BRIDGEPORT, CA  United States          NaN        Fatal(4)
# 2    Saltville, VA  United States          NaN        Fatal(3)
# 3       EUREKA, CA  United States          NaN        Fatal(2)
# 4       Canton, OH  United States          NaN        Fatal(1)
#
#   Aircraft.damage Aircraft.Category  ... Air.carrier Total.Fatal.Injuries  \
# 0       Destroyed               NaN  ...         NaN                  2.0
# ...
